# %% [markdown]
# # $\textbf{Overview}$
# This document provides instructions on running the JWST Science Calibration Pipeline (referred to as “the pipeline”) and individual pipeline steps specifically for <mark>$\textbf{Time Series Observation (TSO) Imaging with NIRCam NRC_TSIMAGE exposure data}$</mark>.
#
# End-to-end calibration of JWST data is divided into 3 main stages of processing. Multiple pipeline modules are used for different stages of processing and for different JWST observing modes. The modules are broken into the following 3 stages:
#
# - $\textbf{Stage 1}$: Detector-level corrections and ramp fitting for individual exposures
#
# - $\textbf{Stage 2}$: Instrument-mode calibrations for individual exposures
#
# - $\textbf{Stage 3}$: Combining data from multiple exposures within an observation
#
# $\textbf{Stage 1}$ corrections are applied nearly universally for all instruments and modes. $\textbf{Stage 2}$ is divided into separate modules for <mark>$\textbf{imaging}$</mark> and spectroscopic modes. $\textbf{Stage 3}$ is divided into five separate modules for imaging, spectroscopic, coronagraphic, Aperture Masking Interferometry (AMI), and <mark>$\textbf{Time Series Observation (TSO)}$</mark> modes.

# %% [markdown]
# # $\textbf{Import Library}$

# %%
import os
#os.environ['CRDS_PATH'] = '/fenrirdata1/kg_data/crds_cache/' #These pathways should be defined in your ~./bash profile. If not, you can set them within the notebook.
#os.environ['CRDS_SERVER_URL']= 'https://jwst-crds.stsci.edu'
#os.environ['CRDS_CONTEXT']='jwst_0756.pmap' #Occasionally, the JWST CRDS pmap will be updated. Updates may break existing code. Use this command to revert to an older working verison until the issue is fixed. 

import jwst
print(jwst.__version__) #Print what version of the pipeline you are using.

from jwst.pipeline.calwebb_detector1 import Detector1Pipeline #Stage 1
from jwst.pipeline.calwebb_image2 import Image2Pipeline #Stage 2
from jwst.pipeline.calwebb_tso3 import Tso3Pipeline #Stage 3
from jwst.associations.asn_from_list import asn_from_list #Association file imports
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase

#General
from astropy.io import fits, ascii
import matplotlib.pyplot as plt
# %matplotlib inline
import csv
import numpy as np
import asdf
import glob
import time
import yaml
from copy import deepcopy


from tshirt.pipeline import phot_pipeline, analysis #tshirt specific imports
from splintegrate import splintegrate

#modeling
import batman
from scipy.optimize import curve_fit

#Style Choice
class style:
   BOLD = '\033[1m'
   END = '\033[0m'
# Out:
# 1.3.1
# Could not import ccdproc, so some CCD-like processing may not work.

# %% [markdown]
# # $\textbf{Stage 1}$
# ### $\textbf{Detector-level corrections and ramp fitting for individual exposures.}$
# Stage 1 consists of detector-level corrections that are performed on a group-by-group basis, followed by ramp fitting.
# The output of stage 1 processing is a countrate image per exposure, or per integration for some modes.
#
# #### $\textbf{Detector1Pipeline:}$
# Apply all calibration steps to raw JWST ramps to produce a 2-D slope product. This stage takes care of basic data reduction steps, such as reference pixel correction, superbias subtraction, removal of non-linearity, and flagging of cosmic rays. In the final step in this stage of the pipeline, line-fitting is performed on each integration. A slope image is created for each integration. The steps in this stage are identical for all data.
#
# There are two general configurations for this pipeline, depending on whether the data are to be treated as a Time Series Observation (TSO). The configuration is provided by CRDS reference file mappings and are usually set by default to always give access to the most recent reference file deliveries and selection rules. For TSO exposures, <mark>some steps are set to be skipped by default</mark>:
#
# - The <mark>$\textbf{ipc}$</mark> step corrects a JWST exposure for interpixel capacitance by convolving with an IPC reference image.
# - The <mark>$\textbf{persistence}$</mark> step. Based on a model, this step computes the number of traps that are expected to have captured or released a charge during an exposure. The released charge is proportional to the persistence signal, and this will be subtracted (group by group) from the science data.
#
# $\textbf{INPUT FILES:}$
# Exposure raw data products are designated by a file name suffix of “uncal.” These files usually contain only the raw detector pixel values from an exposure, with the addition of some table extensions containing various types of meta data associated with the exposure. Additional extensions can be included for certain instruments and readout types. Below are header modifications to the "uncal" fits files.

# %%
#Adding header modifications
all_uncal_files = [] # All Uncalibrated File Names. Also use to check that all files have been modified by the loop. 
BaseDirectory = '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data/'
for fitsName in glob.glob(BaseDirectory + '*nrca3_uncal.fits'): #Grabbing only nrca3 files from the directory
    HDUList = fits.open(fitsName, 'update')
    HDUList[0].header['NOUTPUTS'] = (4, 'Number of output amplifiers') #This was not input at the time of the simulation. Therefore, we manually must input this information. 
    HDUList.close()
    all_uncal_files.append(fitsName)
    
all_uncal_files = sorted(all_uncal_files) #sort files alphabetically. 
#seg01_len=len(glob.glob('/fenrirdata1/kg_data/pipeline_output/WASP80b_WLP8/ROEBA/splintegrate/jw01185002001_01101_00001-seg001*.fits'))

# %%
startTime = time.time() #Time how long this step takes

for filename_stage1 in all_uncal_files:
    
    # Instantiate the class. Do not provide a configuration file.
    pipeline_stage1 = Detector1Pipeline()
    
    # Manually set any desired non-default parameter values
    
    # Default is to skip the persistence and IPC correction
    # Make that explicit here
    pipeline_stage1.persistence.skip = True
    pipeline_stage1.ipc.skip = True
    
    pipeline_stage1.refpix.skip = False # Make sure to skip steps appropriate if using an alternate ref pix correction method. Otherwise, the default is 'False'.
    pipeline_stage1.superbias.skip = False 
    
    # The default value for CR flagging is 3 or 4 sigma
    # which tends to be too aggressive and flags noise.
    # Set it to something more reasonable
    #pipeline_stage1.jump.rejection_threshold = 9
    pipeline_stage1.jump.skip=True # Currently we are skipping this step as we are testing the pipeline with this simulation and lots of the data gets flagged. 
    
    # Specify that you want results saved to a file
    pipeline_stage1.save_results = True
    pipeline_stage1.output_dir = '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/'
    
    # Execute the pipeline using the run method
    result_stage1 = pipeline_stage1.run(filename_stage1)
    
executionTime = (time.time() - startTime)
print('Stage 1 Execution Time in Seconds: ' + str(executionTime)) #Time how long this step takes
# Out:
# 2022-04-05 21:48:28,901 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-04-05 21:48:28,907 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-04-05 21:48:28,913 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-04-05 21:48:28,918 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-04-05 21:48:28,936 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2022-04-05 21:48:28,942 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2022-04-05 21:48:28,948 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2022-04-05 21:48:28,953 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2022-04-05 21:48:28,962 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2022-04-05 21:48:28,966 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2022-04-05 21:48:28,971 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2022-04-05 21:48:28,976 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2022-04-05 21:48:28,981 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2022-04-05 21:48:28,987 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2022-04-05 21:48:28,995 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2022-04-05 21:48:29,001 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2022-04-05 21:48:29,006 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2022-04-05 21:48:29,190 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data/jw01366002001_01101_00001-seg001_nrca3_uncal.fits',).
# 2022-04-05 21:48:29,216 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': T ...
# 2022-04-05 21:49:06,475 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw01366002001_01101_00001-seg001_nrca3_uncal.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'readnoise', 'refpix', 'reset', 'rscd', 'saturation', 'superbias']
# 2022-04-05 21:49:09,041 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_dark_0262.fits'.
# 2022-04-05 21:49:09,044 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_gain_0048.fits'.
# 2022-04-05 21:49:09,046 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0053.fits'.
# 2022-04-05 21:49:09,048 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_mask_0058.fits'.
# 2022-04-05 21:49:09,050 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0030.fits'.
# 2022-04-05 21:49:09,051 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2022-04-05 21:49:09,052 - stpipe.Detector1Pipeline - INFO - Prefetch for RESET reference file is 'N/A'.
# 2022-04-05 21:49:09,054 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is 'N/A'.
# 2022-04-05 21:49:09,055 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0094.fits'.
# 2022-04-05 21:49:09,056 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is '/fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0027.fits'.
# 2022-04-05 21:49:09,059 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2022-04-05 21:49:48,594 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg001_nrca3_uncal.fits>,).
# 2022-04-05 21:49:48,597 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 21:50:08,149 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES=2 is a power of 2; correction not needed
# 2022-04-05 21:50:08,153 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2022-04-05 21:50:08,155 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2022-04-05 21:50:08,350 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg001_nrca3_uncal.fits>,).
# 2022-04-05 21:50:08,353 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 21:50:08,421 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_mask_0058.fits
# 2022-04-05 21:50:37,740 - stpipe.Detector1Pipeline.dq_init - INFO - Extracting mask subarray to match science data
# 2022-04-05 21:50:37,763 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2022-04-05 21:50:38,120 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg001_nrca3_uncal.fits>,).
# 2022-04-05 21:50:38,123 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 21:50:38,172 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0094.fits
# 2022-04-05 21:50:51,770 - stpipe.Detector1Pipeline.saturation - INFO - Extracting reference file subarray to match science data
# 2022-04-05 21:51:05,200 - stpipe.Detector1Pipeline.saturation - INFO - Detected 670 saturated pixels
# 2022-04-05 21:51:09,089 - stpipe.Detector1Pipeline.saturation - INFO - Detected 0 A/D floor pixels
# 2022-04-05 21:51:09,097 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2022-04-05 21:51:10,059 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg001_nrca3_uncal.fits>,).
# 2022-04-05 21:51:10,062 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 21:51:10,063 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2022-04-05 21:51:10,064 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2022-04-05 21:51:10,293 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg001_nrca3_uncal.fits>,).
# 2022-04-05 21:51:10,296 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 21:51:10,356 - stpipe.Detector1Pipeline.superbias - INFO - Using SUPERBIAS reference file /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0027.fits
# 2022-04-05 21:51:10,999 - stpipe.Detector1Pipeline.superbias - WARNING - Keyword NOISY does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 21:51:34,047 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias done
# 2022-04-05 21:51:34,523 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg001_nrca3_uncal.fits>,).
# 2022-04-05 21:51:34,526 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-04-05 21:51:34,548 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# 2022-04-05 21:51:34,549 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# 2022-04-05 21:51:34,551 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# 2022-04-05 21:51:34,552 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.000000
# 2022-04-05 21:51:34,555 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2022-04-05 22:01:49,142 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-04-05 22:01:49,825 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg001_nrca3_uncal.fits>,).
# 2022-04-05 22:01:49,828 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 22:01:49,877 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0053.fits
# 2022-04-05 22:01:50,325 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_DO_NOT_USE does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 22:01:50,327 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_NO_LIN_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 22:01:50,328 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_BAD_LIN_FIT does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 22:01:50,330 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_NO_WELL_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 22:01:50,331 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_MODEL_FIT_FAIL does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 22:01:50,332 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_WELL_NOT_DEFINED does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 22:01:50,334 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_MASTER_MASK does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 22:02:06,733 - stpipe.Detector1Pipeline.linearity - INFO - Extracting linearity subarray to match science data
# 2022-04-05 22:02:35,700 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2022-04-05 22:02:36,076 - stpipe.Detector1Pipeline.persistence - INFO - Step persistence running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg001_nrca3_uncal.fits>,).
# 2022-04-05 22:02:36,079 - stpipe.Detector1Pipeline.persistence - INFO - Step persistence parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data', 'input_trapsfilled': '', 'flag_pers_cutoff': 40.0, 'save_persistence': False, 'save_trapsfilled': True}
# 2022-04-05 22:02:36,081 - stpipe.Detector1Pipeline.persistence - INFO - Step skipped.
# 2022-04-05 22:02:36,083 - stpipe.Detector1Pipeline.persistence - INFO - Step persistence done
# 2022-04-05 22:02:36,312 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg001_nrca3_uncal.fits>,).
# 2022-04-05 22:02:36,315 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data', 'dark_output': None}
# 2022-04-05 22:02:36,362 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_dark_0262.fits
# 2022-04-05 22:02:39,360 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=105, ngroups=12, nframes=2, groupgap=3
# 2022-04-05 22:02:39,361 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=1, ngroups=600, nframes=1, groupgap=0
# 2022-04-05 22:03:02,235 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-04-05 22:03:02,830 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg001_nrca3_uncal.fits>,).
# 2022-04-05 22:03:02,836 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data', 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'none', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0}
# 2022-04-05 22:03:02,837 - stpipe.Detector1Pipeline.jump - INFO - Step skipped.
# 2022-04-05 22:03:02,839 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2022-04-05 22:03:03,064 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg001_nrca3_uncal.fits>,).
# 2022-04-05 22:03:03,067 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data', 'int_name': '', 'save_opt': False, 'opt_name': '', 'maximum_cores': 'none'}
# 2022-04-05 22:03:03,136 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0030.fits
# 2022-04-05 22:03:03,343 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_gain_0048.fits
# 2022-04-05 22:03:03,502 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2022-04-05 22:03:03,504 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2022-04-05 22:03:03,507 - stpipe.Detector1Pipeline.ramp_fit - INFO - Extracting gain subarray to match science data
# 2022-04-05 22:03:03,510 - stpipe.Detector1Pipeline.ramp_fit - INFO - Extracting readnoise subarray to match science data
# 2022-04-05 22:15:38,681 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 12
# 2022-04-05 22:15:38,687 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 105
# 2022-04-05 22:15:39,092 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-04-05 22:15:39,825 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(256, 2048) from jw01366002001_01101_00001-seg001_nrca3_uncal.fits>,).
# 2022-04-05 22:15:39,828 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 22:15:39,914 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-04-05 22:15:39,915 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-04-05 22:15:39,919 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-04-05 22:15:40,062 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(105, 256, 2048) from jw01366002001_01101_00001-seg001_nrca3_uncal.fits>,).
# 2022-04-05 22:15:40,067 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 22:15:40,183 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-04-05 22:15:40,185 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-04-05 22:15:40,192 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-04-05 22:15:42,569 - stpipe.Detector1Pipeline - INFO - Saved model in /fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/jw01366002001_01101_00001-seg001_nrca3_rateints.fits
# 2022-04-05 22:15:42,571 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-04-05 22:15:42,730 - stpipe.Detector1Pipeline - INFO - Saved model in /fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/jw01366002001_01101_00001-seg001_nrca3_rate.fits
# 2022-04-05 22:15:42,734 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2022-04-05 22:15:42,767 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-04-05 22:15:42,770 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-04-05 22:15:42,774 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-04-05 22:15:42,777 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-04-05 22:15:42,780 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2022-04-05 22:15:42,782 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2022-04-05 22:15:42,785 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2022-04-05 22:15:42,792 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2022-04-05 22:15:42,795 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2022-04-05 22:15:42,799 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2022-04-05 22:15:42,802 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2022-04-05 22:15:42,805 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2022-04-05 22:15:42,808 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2022-04-05 22:15:42,812 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2022-04-05 22:15:42,816 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2022-04-05 22:15:42,820 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2022-04-05 22:15:42,825 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2022-04-05 22:15:44,348 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data/jw01366002001_01101_00001-seg002_nrca3_uncal.fits',).
# 2022-04-05 22:15:44,397 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': T ...
# 2022-04-05 22:15:50,246 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw01366002001_01101_00001-seg002_nrca3_uncal.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'readnoise', 'refpix', 'reset', 'rscd', 'saturation', 'superbias']
# 2022-04-05 22:15:50,259 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_dark_0262.fits'.
# 2022-04-05 22:15:50,261 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_gain_0048.fits'.
# 2022-04-05 22:15:50,264 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0053.fits'.
# 2022-04-05 22:15:50,265 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_mask_0058.fits'.
# 2022-04-05 22:15:50,269 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0030.fits'.
# 2022-04-05 22:15:50,270 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2022-04-05 22:15:50,272 - stpipe.Detector1Pipeline - INFO - Prefetch for RESET reference file is 'N/A'.
# 2022-04-05 22:15:50,273 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is 'N/A'.
# 2022-04-05 22:15:50,275 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0094.fits'.
# 2022-04-05 22:15:50,277 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is '/fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0027.fits'.
# 2022-04-05 22:15:50,283 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2022-04-05 22:16:18,456 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg002_nrca3_uncal.fits>,).
# 2022-04-05 22:16:18,460 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 22:16:59,966 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES=2 is a power of 2; correction not needed
# 2022-04-05 22:16:59,971 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2022-04-05 22:16:59,974 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2022-04-05 22:17:00,254 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg002_nrca3_uncal.fits>,).
# 2022-04-05 22:17:00,258 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 22:17:00,308 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_mask_0058.fits
# 2022-04-05 22:17:20,019 - stpipe.Detector1Pipeline.dq_init - INFO - Extracting mask subarray to match science data
# 2022-04-05 22:17:20,043 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2022-04-05 22:17:20,324 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg002_nrca3_uncal.fits>,).
# 2022-04-05 22:17:20,327 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 22:17:20,378 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0094.fits
# 2022-04-05 22:17:26,973 - stpipe.Detector1Pipeline.saturation - INFO - Extracting reference file subarray to match science data
# 2022-04-05 22:17:43,723 - stpipe.Detector1Pipeline.saturation - INFO - Detected 602 saturated pixels
# 2022-04-05 22:17:46,815 - stpipe.Detector1Pipeline.saturation - INFO - Detected 0 A/D floor pixels
# 2022-04-05 22:17:46,824 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2022-04-05 22:17:47,573 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg002_nrca3_uncal.fits>,).
# 2022-04-05 22:17:47,575 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 22:17:47,577 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2022-04-05 22:17:47,578 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2022-04-05 22:17:47,774 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg002_nrca3_uncal.fits>,).
# 2022-04-05 22:17:47,778 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 22:17:47,868 - stpipe.Detector1Pipeline.superbias - INFO - Using SUPERBIAS reference file /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0027.fits
# 2022-04-05 22:17:48,437 - stpipe.Detector1Pipeline.superbias - WARNING - Keyword NOISY does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 22:18:16,539 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias done
# 2022-04-05 22:18:16,795 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg002_nrca3_uncal.fits>,).
# 2022-04-05 22:18:16,798 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-04-05 22:18:16,829 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# 2022-04-05 22:18:16,831 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# 2022-04-05 22:18:16,832 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# 2022-04-05 22:18:16,835 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.000000
# 2022-04-05 22:18:16,837 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2022-04-05 22:27:33,024 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-04-05 22:27:33,907 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg002_nrca3_uncal.fits>,).
# 2022-04-05 22:27:33,910 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 22:27:33,960 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0053.fits
# 2022-04-05 22:27:34,251 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_DO_NOT_USE does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 22:27:34,253 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_NO_LIN_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 22:27:34,254 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_BAD_LIN_FIT does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 22:27:34,256 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_NO_WELL_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 22:27:34,257 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_MODEL_FIT_FAIL does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 22:27:34,259 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_WELL_NOT_DEFINED does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 22:27:34,263 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_MASTER_MASK does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 22:27:55,292 - stpipe.Detector1Pipeline.linearity - INFO - Extracting linearity subarray to match science data
# 2022-04-05 22:28:17,569 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2022-04-05 22:28:17,799 - stpipe.Detector1Pipeline.persistence - INFO - Step persistence running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg002_nrca3_uncal.fits>,).
# 2022-04-05 22:28:17,803 - stpipe.Detector1Pipeline.persistence - INFO - Step persistence parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data', 'input_trapsfilled': '', 'flag_pers_cutoff': 40.0, 'save_persistence': False, 'save_trapsfilled': True}
# 2022-04-05 22:28:17,804 - stpipe.Detector1Pipeline.persistence - INFO - Step skipped.
# 2022-04-05 22:28:17,806 - stpipe.Detector1Pipeline.persistence - INFO - Step persistence done
# 2022-04-05 22:28:17,969 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg002_nrca3_uncal.fits>,).
# 2022-04-05 22:28:17,973 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data', 'dark_output': None}
# 2022-04-05 22:28:18,023 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_dark_0262.fits
# 2022-04-05 22:28:21,087 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=105, ngroups=12, nframes=2, groupgap=3
# 2022-04-05 22:28:21,088 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=1, ngroups=600, nframes=1, groupgap=0
# 2022-04-05 22:28:41,311 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-04-05 22:28:42,189 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg002_nrca3_uncal.fits>,).
# 2022-04-05 22:28:42,192 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data', 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'none', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0}
# 2022-04-05 22:28:42,194 - stpipe.Detector1Pipeline.jump - INFO - Step skipped.
# 2022-04-05 22:28:42,197 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2022-04-05 22:28:42,419 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(105, 12, 256, 2048) from jw01366002001_01101_00001-seg002_nrca3_uncal.fits>,).
# 2022-04-05 22:28:42,422 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data', 'int_name': '', 'save_opt': False, 'opt_name': '', 'maximum_cores': 'none'}
# 2022-04-05 22:28:42,540 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0030.fits
# 2022-04-05 22:28:42,755 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_gain_0048.fits
# 2022-04-05 22:28:43,082 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2022-04-05 22:28:43,087 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2022-04-05 22:28:43,090 - stpipe.Detector1Pipeline.ramp_fit - INFO - Extracting gain subarray to match science data
# 2022-04-05 22:28:43,095 - stpipe.Detector1Pipeline.ramp_fit - INFO - Extracting readnoise subarray to match science data
# 2022-04-05 22:41:13,637 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 12
# 2022-04-05 22:41:13,640 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 105
# 2022-04-05 22:41:14,038 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-04-05 22:41:14,751 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(256, 2048) from jw01366002001_01101_00001-seg002_nrca3_uncal.fits>,).
# 2022-04-05 22:41:14,754 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 22:41:14,857 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-04-05 22:41:14,859 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-04-05 22:41:14,871 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-04-05 22:41:15,047 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(105, 256, 2048) from jw01366002001_01101_00001-seg002_nrca3_uncal.fits>,).
# 2022-04-05 22:41:15,052 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 22:41:15,146 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-04-05 22:41:15,147 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-04-05 22:41:15,151 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-04-05 22:41:17,035 - stpipe.Detector1Pipeline - INFO - Saved model in /fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/jw01366002001_01101_00001-seg002_nrca3_rateints.fits
# 2022-04-05 22:41:17,037 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-04-05 22:41:17,211 - stpipe.Detector1Pipeline - INFO - Saved model in /fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/jw01366002001_01101_00001-seg002_nrca3_rate.fits
# 2022-04-05 22:41:17,212 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2022-04-05 22:41:17,243 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-04-05 22:41:17,248 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-04-05 22:41:17,253 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-04-05 22:41:17,261 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-04-05 22:41:17,266 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# ...
# 2022-04-05 23:07:41,083 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2022-04-05 23:07:44,138 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(63, 12, 256, 2048) from jw01366002001_01101_00001-seg004_nrca3_uncal.fits>,).
# 2022-04-05 23:07:44,143 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 23:07:46,160 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES=2 is a power of 2; correction not needed
# 2022-04-05 23:07:46,162 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2022-04-05 23:07:46,164 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2022-04-05 23:07:46,292 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(63, 12, 256, 2048) from jw01366002001_01101_00001-seg004_nrca3_uncal.fits>,).
# 2022-04-05 23:07:46,295 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 23:07:46,343 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_mask_0058.fits
# 2022-04-05 23:07:52,639 - stpipe.Detector1Pipeline.dq_init - INFO - Extracting mask subarray to match science data
# 2022-04-05 23:07:52,665 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2022-04-05 23:07:52,890 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(63, 12, 256, 2048) from jw01366002001_01101_00001-seg004_nrca3_uncal.fits>,).
# 2022-04-05 23:07:52,893 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 23:07:52,952 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0094.fits
# 2022-04-05 23:07:57,680 - stpipe.Detector1Pipeline.saturation - INFO - Extracting reference file subarray to match science data
# 2022-04-05 23:08:04,322 - stpipe.Detector1Pipeline.saturation - INFO - Detected 438 saturated pixels
# 2022-04-05 23:08:05,051 - stpipe.Detector1Pipeline.saturation - INFO - Detected 0 A/D floor pixels
# 2022-04-05 23:08:05,061 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2022-04-05 23:08:05,366 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(63, 12, 256, 2048) from jw01366002001_01101_00001-seg004_nrca3_uncal.fits>,).
# 2022-04-05 23:08:05,369 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 23:08:05,371 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2022-04-05 23:08:05,373 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2022-04-05 23:08:05,581 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(63, 12, 256, 2048) from jw01366002001_01101_00001-seg004_nrca3_uncal.fits>,).
# 2022-04-05 23:08:05,584 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 23:08:05,631 - stpipe.Detector1Pipeline.superbias - INFO - Using SUPERBIAS reference file /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0027.fits
# 2022-04-05 23:08:05,939 - stpipe.Detector1Pipeline.superbias - WARNING - Keyword NOISY does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 23:08:10,701 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias done
# 2022-04-05 23:08:10,927 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(63, 12, 256, 2048) from jw01366002001_01101_00001-seg004_nrca3_uncal.fits>,).
# 2022-04-05 23:08:10,931 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-04-05 23:08:10,955 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# 2022-04-05 23:08:10,957 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# 2022-04-05 23:08:10,958 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# 2022-04-05 23:08:10,959 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.000000
# 2022-04-05 23:08:10,962 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2022-04-05 23:13:51,388 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-04-05 23:13:51,601 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(63, 12, 256, 2048) from jw01366002001_01101_00001-seg004_nrca3_uncal.fits>,).
# 2022-04-05 23:13:51,605 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 23:13:51,687 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0053.fits
# 2022-04-05 23:13:51,952 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_DO_NOT_USE does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 23:13:51,954 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_NO_LIN_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 23:13:51,956 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_BAD_LIN_FIT does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 23:13:51,958 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_NO_WELL_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 23:13:51,959 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_MODEL_FIT_FAIL does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 23:13:51,961 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_WELL_NOT_DEFINED does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 23:13:51,962 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_MASTER_MASK does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-05 23:13:55,052 - stpipe.Detector1Pipeline.linearity - INFO - Extracting linearity subarray to match science data
# 2022-04-05 23:14:09,265 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2022-04-05 23:14:09,509 - stpipe.Detector1Pipeline.persistence - INFO - Step persistence running with args (<RampModel(63, 12, 256, 2048) from jw01366002001_01101_00001-seg004_nrca3_uncal.fits>,).
# 2022-04-05 23:14:09,512 - stpipe.Detector1Pipeline.persistence - INFO - Step persistence parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data', 'input_trapsfilled': '', 'flag_pers_cutoff': 40.0, 'save_persistence': False, 'save_trapsfilled': True}
# 2022-04-05 23:14:09,514 - stpipe.Detector1Pipeline.persistence - INFO - Step skipped.
# 2022-04-05 23:14:09,517 - stpipe.Detector1Pipeline.persistence - INFO - Step persistence done
# 2022-04-05 23:14:09,702 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(63, 12, 256, 2048) from jw01366002001_01101_00001-seg004_nrca3_uncal.fits>,).
# 2022-04-05 23:14:09,706 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data', 'dark_output': None}
# 2022-04-05 23:14:09,756 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_dark_0262.fits
# 2022-04-05 23:14:18,406 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=63, ngroups=12, nframes=2, groupgap=3
# 2022-04-05 23:14:18,408 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=1, ngroups=600, nframes=1, groupgap=0
# 2022-04-05 23:14:24,662 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-04-05 23:14:25,010 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(63, 12, 256, 2048) from jw01366002001_01101_00001-seg004_nrca3_uncal.fits>,).
# 2022-04-05 23:14:25,014 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data', 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'none', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0}
# 2022-04-05 23:14:25,016 - stpipe.Detector1Pipeline.jump - INFO - Step skipped.
# 2022-04-05 23:14:25,017 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2022-04-05 23:14:25,197 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(63, 12, 256, 2048) from jw01366002001_01101_00001-seg004_nrca3_uncal.fits>,).
# 2022-04-05 23:14:25,200 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data', 'int_name': '', 'save_opt': False, 'opt_name': '', 'maximum_cores': 'none'}
# 2022-04-05 23:14:25,275 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0030.fits
# 2022-04-05 23:14:25,309 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /fenrirdata1/kg_data/crds_cache/references/jwst/nircam/jwst_nircam_gain_0048.fits
# 2022-04-05 23:14:25,371 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2022-04-05 23:14:25,373 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2022-04-05 23:14:25,374 - stpipe.Detector1Pipeline.ramp_fit - INFO - Extracting gain subarray to match science data
# 2022-04-05 23:14:25,377 - stpipe.Detector1Pipeline.ramp_fit - INFO - Extracting readnoise subarray to match science data
# 2022-04-05 23:21:48,104 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 12
# 2022-04-05 23:21:48,106 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 63
# 2022-04-05 23:21:48,376 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-04-05 23:21:48,621 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(256, 2048) from jw01366002001_01101_00001-seg004_nrca3_uncal.fits>,).
# 2022-04-05 23:21:48,624 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 23:21:48,719 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-04-05 23:21:48,721 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-04-05 23:21:48,724 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-04-05 23:21:48,851 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(63, 256, 2048) from jw01366002001_01101_00001-seg004_nrca3_uncal.fits>,).
# 2022-04-05 23:21:48,854 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/Raw_Data'}
# 2022-04-05 23:21:48,939 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-04-05 23:21:48,941 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-04-05 23:21:48,944 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-04-05 23:21:50,050 - stpipe.Detector1Pipeline - INFO - Saved model in /fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/jw01366002001_01101_00001-seg004_nrca3_rateints.fits
# 2022-04-05 23:21:50,052 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-04-05 23:21:50,218 - stpipe.Detector1Pipeline - INFO - Saved model in /fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/jw01366002001_01101_00001-seg004_nrca3_rate.fits
# 2022-04-05 23:21:50,219 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# Stage 1 Execution Time in Seconds: 5601.388343095779

# %% [markdown]
# $\textbf{OUTPUT FILES:}$ Output files are \*rateints.fits. The pipeline creates a rate.fits and a rateint.fits files in cases where there is more than one integration in a file, but only a rate.fits file in the case where there is only one integration in a file.

# %%
all_rateints_files = [] # All Rateints File Names. Also used to check that all the rateints file exist.  
BaseDirectory = '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/'
for fitsName in glob.glob(BaseDirectory + '*nrca3_rateints.fits'): #Grabbing only nrca3 files from the directory
    all_rateints_files.append(fitsName)

# %% [markdown]
# ### $\textbf{Confirming a Source}$
# Plotting one of the rateints.fits files to check that a target source is present before moving on to stage 2 and stage 3.

# %%
#A check to ensure the star is in the file
file = '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/jw01366002001_01101_00001-seg001_nrca3_rateints.fits' #random file from the rateints list
HDUList = fits.open(file)
#HDUList.info()

image2D = HDUList[1].data[0]
image2D.shape

fig, ax = plt.subplots(figsize=(22,5))
ax.imshow(image2D, vmin=0, vmax=40)
#ax.plot(image2D[32,:])
#ax.set_xlim(900,1000)
# Out:
# 2022-04-11 22:25:52,049 - stpipe - WARNING - /tmp/ipykernel_1720270/1815678211.py:3: ResourceWarning: unclosed file <_io.FileIO name='/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/jw01366002001_01101_00001-seg001_nrca3_rateints.fits' mode='rb' closefd=True>
#   HDUList = fits.open(file)

# %% [markdown]
# #### $\textbf{Split the Integrations for tshirt (referenced later)}$

# %%
#splitegrate
#Splintegrate splits and combines integrations from the pipeline up.
#Set flipToDet = False to not flip the x-axis
#This is a step required if running tshirt

#This simulation has multiple segments that need to be split for tshirt purposes.
BaseDirectory = '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/'
for rateints_segment in glob.glob(BaseDirectory + '*nrca3_rateints.fits'): #Grabbing only nrca3 files from the directory
    outDir = '/fenrirdata1/kg_data/pipeline_output/WASP39b_WLP8/WASP39b_WLP8_SYS/splintegrate/'
    splint = splintegrate.splint(inFile=rateints_segment,outDir=outDir,flipToDet=False)
    splint.split()
# Out:
# 100%|█████████████████████████████████████████| 105/105 [00:04<00:00, 24.29it/s]
# 100%|█████████████████████████████████████████| 105/105 [00:02<00:00, 48.27it/s]
# 100%|█████████████████████████████████████████| 105/105 [00:02<00:00, 51.45it/s]
# 100%|███████████████████████████████████████████| 63/63 [00:01<00:00, 48.82it/s]
